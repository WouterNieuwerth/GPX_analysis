# %% [markdown]
# https://towardsdatascience.com/how-tracking-apps-analyse-your-gps-data-a-hands-on-tutorial-in-python-756d4db6715d
# https://towardsdatascience.com/how-to-make-your-pandas-loop-71-803-times-faster-805030df4f06
# https://realpython.com/fast-flexible-pandas/

# %%
# !pip install haversine
# Out:
# Requirement already satisfied: haversine in /Users/wouternieuwerth/Applications/Anaconda/anaconda3/lib/python3.7/site-packages (2.2.0)

# %%
import gpxpy
import matplotlib.pyplot as plt
import datetime
from geopy import distance
from math import sqrt, floor
import numpy as np
import pandas as pd
import haversine
import os
import re

# %%
from os import listdir
from os.path import isfile, join
path = os.path.join(os.path.abspath(''), 'tracks')
allfiles = [f for f in listdir(path) if isfile(join(path, f))]

# Probleemgevallen verwijderen:
# while '20120704_192600.gpx' in allfiles: allfiles.remove('20120704_192600.gpx')
while '20170429_123929.gpx' in allfiles: allfiles.remove('20170429_123929.gpx')
while '.DS_Store' in allfiles: allfiles.remove('.DS_Store')

print(allfiles)
# Out:
# ['20150201_105601.gpx', '20180325_090235.gpx', '20121127_191701.gpx', '20160518_165805.gpx', 'Nieuwe Asics GT4000.gpx', '20180819_084758.gpx', '20190407_084824.gpx', '20150411_085108.gpx', '20120827_192731.gpx', '20191012_091115.gpx', '20190928_082644.gpx', '20140405_082329.gpx', '20191117_101539.gpx', '20191120_194720.gpx', '20170401_080131.gpx', '20121008_175600.gpx', '20190203_094709.gpx', '20160825_163509.gpx', '20170429_113634.gpx', 'Running 5_4_12 10_44 pm.gpx', '20121109_204410.gpx', '20160703_092613.gpx', '20150818_161456.gpx', '20190317_094119.gpx', '20171008_074753.gpx', '20121215_102614.gpx', '20151219_094829.gpx', '20120704_192600.gpx', '20190528_184901.gpx', '20180303_095013.gpx', '20170925_183951.gpx', '20150811_162530.gpx', 'Running 5_15_12 10_04 pm.gpx', '20190130_182900.gpx', '20190120_090601.gpx', '20140215_085202.gpx', '10k met de Enschede Marathon 2019.gpx', '20190521_170801.gpx', 'Running 5_19_12 9_42 am.gpx', '20140329_104844.gpx', '20190507_172037.gpx', '20190402_171716.gpx', '20150716_183510.gpx', '20190303_082619.gpx', '20190113_104804.gpx', '20150207_110201.gpx', '20190706_083133.gpx', '20200122_182418.gpx', '20160130_161732.gpx', '20160203_175256.gpx', '20180217_083728.gpx', '20181125_084859.gpx', '20190224_092728.gpx', '20170906_180527.gpx', '20160626_092352.gpx', '20160221_103829.gpx', '20190821_181522.gpx', '20150919_083904.gpx', '20190324_105525.gpx', '20180915_082344.gpx', '20200118_100022.gpx', '20150909_182321.gpx', '20190911_174246.gpx', '20180224_094149.gpx', '20130105_094608.gpx', '20191130_102113.gpx', '20140222_092036.gpx', '20190314_192617.gpx', '20181117_081847.gpx', '20190616_092444.gpx', '20200111_093849.gpx', '20190811_083308.gpx', '20140301_090444.gpx', '20180616_075653.gpx', '20180831_170702.gpx', '20191205_185918.gpx', '20120920_181000.gpx', '20120614_192813.gpx', '20150620_082416.gpx', '20190421_073837.gpx', '20191023_174537.gpx', '20181028_081559.gpx', 'Wiezoloop.gpx', '20190109_201809.gpx', 'Running 4_26_12 9_58 pm.gpx', '20180603_092713.gpx', '20180825_070302.gpx', '20180909_073130.gpx', '20121231_111118.gpx', '20161104_142826.gpx', '20190501_175443.gpx', '20160120_175404.gpx', '20190424_181244.gpx', '20120820_185706.gpx', '20120814_173934.gpx', '20160817_164956.gpx', '20191027_092557.gpx', 'Halve marathon Enschede.gpx', '20191217_185651.gpx', '20160224_171548.gpx', '20180713_180802.gpx', '20140615_101814.gpx', '20160326_150642.gpx', '20160515_084938.gpx', '20180402_091044.gpx', '20190713_155352.gpx', '20180929_080315.gpx', '20150706_195141.gpx', '20180608_165753.gpx', '20121208_115410.gpx', '20120622_205613.gpx', '20120618_202744.gpx', '20151115_091549.gpx', '20160814_094338.gpx', '20180720_062009.gpx', '20180913_183018.gpx', '20190908_093241.gpx', '20170516_163955.gpx', '20121120_194450.gpx', 'Singelloop Enschede.gpx', '20140125_085023.gpx', '20190726_083403.gpx', '20140201_103400.gpx', '20150815_154919.gpx', '20160305_085533.gpx', '20190428_080331.gpx', '20190518_075535.gpx', '20150826_163448.gpx', '20170920_180418.gpx', '20160323_173701.gpx', '20130319_185542.gpx', '20190829_173115.gpx', '20160630_164212.gpx', '20160523_163111.gpx', '20130128_205103.gpx', '20140412_083500.gpx', '20130222_174706.gpx', 'Singelloop 2016.gpx', '20120622_203116.gpx', '20160117_145715.gpx', '20200129_184439.gpx', '20160308_173335.gpx', '20120710_183400.gpx', '20181008_172836.gpx', '20160501_092158.gpx', '20160312_144343.gpx', '20200104_132943.gpx', '20160614_164240.gpx', '20130217_121623.gpx', '20150906_073706.gpx', '20121102_185117.gpx', '20160814_090812.gpx', '20190306_200757.gpx', '20181021_083844.gpx', '20150117_092343.gpx', '20190709_180805.gpx', '20121022_185130.gpx', '20160210_204632.gpx', '20140510_082700.gpx', '20181110_083336.gpx', '20190310_100210.gpx', '20160330_164400.gpx', '20190321_183502.gpx', '20180423_190336.gpx', '20190804_084836.gpx', '20151005_162739.gpx', '20120902_090425.gpx', '20190418_172525.gpx', '20190915_074118.gpx', '20181031_191224.gpx', 'Running 4_14_12 1_41 pm.gpx ...

# %%
sections = [1000,(1000*1.60934),3000,5000,(5000*1.60934),10000,15000,(10000*1.60934),20000,21097.5,25000,30000,40000,42195]
# sections = [15000]

df_final = pd.DataFrame(columns=['time', 'distance', 'minutes_per_kilometer'])

for file in allfiles:
    
    print('File:', file)
    
    path = os.path.join(os.path.abspath(''), 'tracks', file)

    gpx_file = open(path, 'r')
    gpx = gpxpy.parse(gpx_file)
    
    df = pd.DataFrame(columns=['lon', 'lat', 'alt', 'time'])
    
    # -----------------------------------------------------
    # Inlezen van alle files geeft problemen, omdat de bestanden verschillen van elkaar.
    
    if re.search('^Running', file) is None: # Als de bestandsnaam niet begint met 'Running', dan is het een Endomondo file
        
        if len(gpx.tracks[0].segments) == 1: # Soms komt het voor dat een bestand maar uit 1 segment bestaat, ook bij Endomondo.
            
            segment = gpx.tracks[0].segments[0]
            
            data = segment.points

            for point in data:
                df = df.append({'lon': point.longitude, 'lat' : point.latitude, 'alt' : point.elevation, 'time' : point.time}, ignore_index=True)
            
        else: 
            for segment in gpx.tracks[0].segments[:-1]: # alle segments, behalve de laatste.

                data = segment.points

                for point in data:
                    df = df.append({'lon': point.longitude, 'lat' : point.latitude, 'alt' : point.elevation, 'time' : point.time}, ignore_index=True)
            
    else: # Als de bestandsnaam wel met 'Running' begint, dan is het een oud bestand. Daarvan moeten we alle segments inlezen.
        
        for segment in gpx.tracks[0].segments: # alle segments, behalve de laatste.

            data = segment.points

            for point in data:
                df = df.append({'lon': point.longitude, 'lat' : point.latitude, 'alt' : point.elevation, 'time' : point.time}, ignore_index=True)

    # -----------------------------------------------------
    
    df = df.sort_values(by=['time'])
    df = df.reset_index()
            
    df = df.fillna(method='ffill')
    df = df.fillna(method='bfill')

    # Create a column with values that are 'shifted' one backwards, so we can create calculations for differences.
    df['lon-start'] = df['lon']
    df['lon-start'].iloc[-1] = np.nan
    df['lon-start'] = np.roll(df['lon-start'], 1)
    df['lat-start'] = df['lat']
    df['lat-start'].iloc[-1] = np.nan
    df['lat-start'] = np.roll(df['lat-start'], 1)
    df['alt-start'] = df['alt']
    df['alt-start'].iloc[-1] = np.nan
    df['alt-start'] = np.roll(df['alt-start'], 1)
    df['time-start'] = df['time']
    df['time-start'].iloc[-1] = np.nan
    df['time-start'] = np.roll(df['time-start'], 1)
    df = df.fillna(method='bfill')

    df['time'] = pd.to_datetime(df['time'], utc=True)
    df['time'] = df['time'].dt.tz_localize(tz=None)
    df['time-start'] = pd.to_datetime(df['time-start'], utc=True)
    df['time-start'] = df['time-start'].dt.tz_localize(tz=None)

    #Calculate distances and time deltas
    df['distance_dis_2d'] = df.apply(lambda x: distance.distance((x['lat-start'], x['lon-start']), (x['lat'], x['lon'])).m, axis = 1)
    df['alt_dif'] = df.apply(lambda x: x['alt-start'] - x['alt'], axis=1)
    df['distance_dis_3d'] = df.apply(lambda x: sqrt(x['distance_dis_2d']**2 + (x['alt_dif'])**2), axis=1)
    df['time_delta'] = df.apply(lambda x: (x['time'] - x['time-start']).total_seconds(), axis=1)
    
    df_selected = df.loc[:, ['distance_dis_3d','time_delta']]

    df_selected['distance_cumsum'] = df_selected['distance_dis_3d'].cumsum()
    df_selected['time_cumsum'] = df_selected['time_delta'].cumsum()
    
    # Hier komt de loop voor sections
    for section in sections:
    
        if df['distance_dis_3d'].sum() < section: # Als deze ronde kleiner is dan de afstand die we zoeken hoeven we ook niet verder te rekenen.
            # print('  -- Afstand die we zoeken niet behaald.')
            continue
            
        print(' - Section:', section)
        df_output = pd.DataFrame(columns=['date', 'section', 'filename', 'time', 'distance', 'minutes_per_kilometer', 'total_distance', 'total_time'])

        for i in range(len(df_selected.index)):

            df_section = df_selected[(df_selected['distance_cumsum'] - df_selected['distance_cumsum'].iat[i]) >= section]
            if(len(df_section.index) != 0):
                time = df_section['time_cumsum'].iat[0] - df_selected['time_cumsum'].iat[i]
                distance_i = df_section['distance_cumsum'].iat[0] - df_selected['distance_cumsum'].iat[i]
                minutes_per_kilometer = (time/60)/(distance_i/1000)
                df_output = df_output.append({'date': df['time'].min(), 'section': section, 'filename': file, 'time': time, 'distance': distance_i, 'minutes_per_kilometer': minutes_per_kilometer, 'total_distance': df['distance_dis_3d'].sum(), 'total_time': df['time_delta'].sum()}, ignore_index=True)

        if df_output.empty == True:
            print('Error?!')
        else:
            s_best = df_output.loc[df_output['minutes_per_kilometer'].idxmin()]
            df_final = df_final.append(s_best)
        
df_final['start_index_best_section'] = df_final.index
df_final = df_final.set_index(['filename','section'])

print('Finished!')
# Out:
# File: 20150201_105601.gpx
# /Users/wouternieuwerth/Applications/Anaconda/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/wouternieuwerth/Applications/Anaconda/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:1177: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   a = asanyarray(a)
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180325_090235.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20121127_191701.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20160518_165805.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: Nieuwe Asics GT4000.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180819_084758.gpx
#  - Section: 1000
#  - Section: 1609.34
# File: 20190407_084824.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20150411_085108.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20120827_192731.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20191012_091115.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
#  - Section: 20000
#  - Section: 21097.5
# File: 20190928_082644.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20140405_082329.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20191117_101539.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20191120_194720.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20170401_080131.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20121008_175600.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190203_094709.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20160825_163509.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20170429_113634.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: Running 5_4_12 10_44 pm.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20121109_204410.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20160703_092613.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20150818_161456.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190317_094119.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20171008_074753.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20121215_102614.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20151219_094829.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20120704_192600.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20190528_184901.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20180303_095013.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20170925_183951.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20150811_162530.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: Running 5_15_12 10_04 pm.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190130_182900.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190120_090601.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20140215_085202.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 10k met de Enschede Marathon 2019.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190521_170801.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: Running 5_19_12 9_42 am.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20140329_104844.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190507_172037.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190402_171716.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20150716_183510.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20190303_082619.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190113_104804.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20150207_110201.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20190706_083133.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20200122_182418.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160130_161732.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160203_175256.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180217_083728.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20181125_084859.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
# File: 20190224_092728.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20170906_180527.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20160626_092352.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160221_103829.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20190821_181522.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20150919_083904.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20190324_105525.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20180915_082344.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20200118_100022.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
#  - Section: 20000
#  - Section: 21097.5
# File: 20150909_182321.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190911_174246.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20180224_094149.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20130105_094608.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20191130_102113.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20140222_092036.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190314_192617.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20181117_081847.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20190616_092444.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20200111_093849.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20190811_083308.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20140301_090444.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180616_075653.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20180831_170702.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20191205_185918.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20120920_181000.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20120614_192813.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20150620_082416.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190421_073837.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20191023_174537.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20181028_081559.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: Wiezoloop.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190109_201809.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: Running 4_26_12 9_58 pm.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180603_092713.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20180825_070302.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20180909_073130.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20121231_111118.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20161104_142826.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20190501_175443.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20160120_175404.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190424_181244.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20120820_185706.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20120814_173934.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160817_164956.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20191027_092557.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: Halve marathon Enschede.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
#  - Section: 20000
#  - Section: 21097.5
# File: 20191217_185651.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160224_171548.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180713_180802.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20140615_101814.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160326_150642.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20160515_084938.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180402_091044.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190713_155352.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20180929_080315.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20150706_195141.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180608_165753.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20121208_115410.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20120622_205613.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20120618_202744.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20151115_091549.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160814_094338.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180720_062009.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180913_183018.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20190908_093241.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20170516_163955.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20121120_194450.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: Singelloop Enschede.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20140125_085023.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20190726_083403.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20140201_103400.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20150815_154919.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160305_085533.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190428_080331.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190518_075535.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20150826_163448.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20170920_180418.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160323_173701.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20130319_185542.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190829_173115.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160630_164212.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160523_163111.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20130128_205103.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20140412_083500.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20130222_174706.gpx
#  - Section: 1000
#  - Section: 1609.34
# File: Singelloop 2016.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20120622_203116.gpx
#  - Section: 1000
#  - Section: 1609.34
# File: 20160117_145715.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20200129_184439.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160308_173335.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20120710_183400.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20181008_172836.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160501_092158.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160312_144343.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20200104_132943.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20160614_164240.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20130217_121623.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20150906_073706.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20121102_185117.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160814_090812.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20190306_200757.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20181021_083844.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
# File: 20150117_092343.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190709_180805.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20121022_185130.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20160210_204632.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20140510_082700.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20181110_083336.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190310_100210.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20160330_164400.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190321_183502.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180423_190336.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190804_084836.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20151005_162739.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20120902_090425.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190418_172525.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20190915_074118.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
#  - Section: 20000
#  - Section: 21097.5
# File: 20181031_191224.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: Running 4_14_12 1_41 pm.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20180804_080107.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160822_155306.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20131103_092610.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20150902_163828.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20170405_164311.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160611_080851.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20160806_082946.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20160406_163104.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160511_170412.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20190226_190533.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190919_180746.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190214_162603.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20191020_095125.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20181202_100638.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190604_181113.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: Batavierenrace.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20160227_152226.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
#  - Section: 20000
#  - Section: 21097.5
# File: 20160605_082500.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20140208_092226.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160410_125240.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
# File: 20191123_103428.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20200108_184736.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160113_200327.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20191005_071643.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20170805_152159.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180528_181636.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160127_204748.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20120911_183017.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160829_193834.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: Running 5_27_12 7_27 pm.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20190815_181209.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20120627_191504.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160709_081615.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190116_193958.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20121002_175903.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190601_071446.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20170324_174513.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190330_091603.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190105_093723.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190126_094315.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20190703_173624.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160402_122753.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
#  - Section: 20000
# File: 20160905_190730.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20170316_175152.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20160206_151300.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20150830_064310.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20200114_191822.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20150110_095210.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: Running 4_21_12 9_58 am.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: Running 5_11_12 11_04 pm.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20200202_111242.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20140316_093701.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160725_170516.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160123_141935.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20160730_164244.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160714_164620.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20160716_083152.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20180517_180947.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20191128_182601.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20160215_174530.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20140503_090500.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20120927_070800.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20200125_104602.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20131022_185221.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20190512_070120.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20140622_091048.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180811_072945.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20120717_185311.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20130204_191521.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20181013_083416.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190807_190037.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20151213_084058.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20150822_091147.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: Nieuwe Asics schoenen.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20170412_183641.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20180317_103324.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190717_192828.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20200116_182543.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20190925_180922.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190525_092836.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20180624_084205.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20190731_152601.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20191221_110307.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20150712_084426.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20120916_094022.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20121016_183311.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20130416_172103.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190218_190538.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20190514_180750.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20191002_172159.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20160529_093428.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
# File: 20191208_115426.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
# File: Running 4_28_12 10_33 am.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
# File: 20190818_081719.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
# File: 20190824_080355.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
#  - Section: 15000
#  - Section: 16093.4
# File: 20160316_200401.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# File: 20191211_081322.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
#  - Section: 8046.7
#  - Section: 10000
# File: 20170723_152756.gpx
#  - Section: 1000
#  - Section: 1609.34
#  - Section: 3000
#  - Section: 5000
# Finished!

# %%
df_final
# Out:
#                                 time      distance  minutes_per_kilometer  \
# filename            section
# 20150201_105601.gpx 1000.00    292.0   1001.160200               4.861027
#                     1609.34    476.0   1621.970891               4.891169
#                     3000.00    894.0   3028.741663               4.919535
#                     5000.00   1498.0   5014.780916               4.978616
# 20180325_090235.gpx 1000.00    288.0   1004.653776               4.777765
# ...                              ...           ...                    ...
# 20191211_081322.gpx 10000.00  3031.0  10000.482595               5.051423
# 20170723_152756.gpx 1000.00    293.0   1017.739969               4.798213
#                     1609.34    482.0   1628.693267               4.932380
#                     3000.00    907.0   3021.953078               5.002284
#                     5000.00   1498.0   5000.565117               4.992769
#
#                                             date  total_distance  total_time  \
# filename            section
# 20150201_105601.gpx 1000.00  2015-02-01 10:56:01     7060.048833      2163.0
#                     1609.34  2015-02-01 10:56:01     7060.048833      2163.0
#                     3000.00  2015-02-01 10:56:01     7060.048833      2163.0
#                     5000.00  2015-02-01 10:56:01     7060.048833      2163.0
# 20180325_090235.gpx 1000.00  2018-03-25 09:02:35     5993.427951      1789.0
# ...                                          ...             ...         ...
# 20191211_081322.gpx 10000.00 2019-12-11 08:13:22    13303.634864      4053.0
# 20170723_152756.gpx 1000.00  2017-07-23 15:27:56     5000.565117      1504.0
#                     1609.34  2017-07-23 15:27:56     5000.565117      1504.0
#                     3000.00  2017-07-23 15:27:56     5000.565117      1504.0
#                     5000.00  2017-07-23 15:27:56     5000.565117      1504.0
#
#                               start_index_best_section
# filename            section
# 20150201_105601.gpx 1000.00                        116
#                     1609.34                        111
#                     3000.00                         52
#                     5000.00                          1
# 20180325_090235.gpx 1000.00                        302
# ...                                                ...
# 20191211_081322.gpx 10000.00                       691
# 20170723_152756.gpx 1000.00                        186
#                     1609.34                        158
#                     3000.00                         91
#                     5000.00                          1
#
# [1350 rows x 7 columns]

# %%
df_final.to_csv('test.csv')

# %%
df_input = pd.read_csv('test.csv', header=0, index_col=[0,1])

# %%
df_final.unstack()
# Out:
#                                           time                             \
# section                               1000.00  1609.34  3000.00  5000.00
# filename
# 10k met de Enschede Marathon 2019.gpx    251.0    418.0    792.0   1329.0
# 20120614_192813.gpx                      282.0    469.0    878.0   1483.0
# 20120618_202744.gpx                      260.0    437.0    826.0   1400.0
# 20120622_203116.gpx                      288.0    481.0      NaN      NaN
# 20120622_205613.gpx                      283.0    477.0    895.0   1511.0
# ...                                        ...      ...      ...      ...
# Running 5_27_12 7_27 pm.gpx              293.0    484.0    907.0   1529.0
# Running 5_4_12 10_44 pm.gpx              304.0    492.0    926.0   1575.0
# Singelloop 2016.gpx                      260.0    417.0    781.0   1310.0
# Singelloop Enschede.gpx                  260.0    424.0    799.0   1335.0
# Wiezoloop.gpx                            246.0    399.0    764.0   1298.0
#
#                                                                            \
# section                               8046.70  10000.00 15000.00 16093.40
# filename
# 10k met de Enschede Marathon 2019.gpx   2162.0   2730.0      NaN      NaN
# 20120614_192813.gpx                     2466.0   3105.0      NaN      NaN
# 20120618_202744.gpx                        NaN      NaN      NaN      NaN
# 20120622_203116.gpx                        NaN      NaN      NaN      NaN
# 20120622_205613.gpx                        NaN      NaN      NaN      NaN
# ...                                        ...      ...      ...      ...
# Running 5_27_12 7_27 pm.gpx             2474.0      NaN      NaN      NaN
# Running 5_4_12 10_44 pm.gpx                NaN      NaN      NaN      NaN
# Singelloop 2016.gpx                     2117.0      NaN      NaN      NaN
# Singelloop Enschede.gpx                 2176.0      NaN      NaN      NaN
# Wiezoloop.gpx                           2133.0   2646.0      NaN      NaN
#
#                                                          ...  \
# section                               20000.00 21097.50  ...
# filename                                                 ...
# 10k met de Enschede Marathon 2019.gpx      NaN      NaN  ...
# 20120614_192813.gpx                        NaN      NaN  ...
# 20120618_202744.gpx                        NaN      NaN  ...
# 20120622_203116.gpx                        NaN      NaN  ...
# 20120622_205613.gpx                        NaN      NaN  ...
# ...                                        ...      ...  ...
# Running 5_27_12 7_27 pm.gpx                NaN      NaN  ...
# Running 5_4_12 10_44 pm.gpx                NaN      NaN  ...
# Singelloop 2016.gpx                        NaN      NaN  ...
# Singelloop Enschede.gpx                    NaN      NaN  ...
# Wiezoloop.gpx                              NaN      NaN  ...
#
#                                       start_index_best_section           \
# section                                               1000.00  1609.34
# filename
# 10k met de Enschede Marathon 2019.gpx                   1600.0   1559.0
# 20120614_192813.gpx                                        3.0      3.0
# 20120618_202744.gpx                                      280.0    245.0
# 20120622_203116.gpx                                       41.0      1.0
# 20120622_205613.gpx                                      270.0     79.0
# ...                                                        ...      ...
# Running 5_27_12 7_27 pm.gpx                              518.0    149.0
# Running 5_4_12 10_44 pm.gpx                               65.0    113.0
# Singelloop 2016.gpx                                      180.0    174.0
# Singelloop Enschede.gpx                                  289.0    265.0
# Wiezoloop.gpx                                             26.0     30.0
#
#                                                                            \
# section                               3000.00  5000.00  8046.70  10000.00
# filename
# 10k met de Enschede Marathon 2019.gpx    686.0    882.0    347.0     22.0
# 20120614_192813.gpx                        3.0      3.0      3.0      2.0
# 20120618_202744.gpx                      169.0     51.0      NaN      NaN
# 20120622_203116.gpx                        NaN      NaN      NaN      NaN
# 20120622_205613.gpx                       12.0     28.0      NaN      NaN
# ...                                        ...      ...      ...      ...
# Running 5_27_12 7_27 pm.gpx              114.0    122.0     37.0      NaN
# Running 5_4_12 10_44 pm.gpx               29.0     31.0      NaN      NaN
# Singelloop 2016.gpx                       99.0     99.0      6.0      NaN
# Singelloop Enschede.gpx                  208.0    127.0      1.0      NaN
# Wiezoloop.gpx                             12.0     12.0     12.0     12.0
#
#
# section                               15000.00 16093.40 20000.00 21097.50
# filename
# 10k met de Enschede Marathon 2019.gpx      NaN      NaN      NaN      NaN
# 20120614_192813.gpx                        NaN      NaN      NaN      NaN
# 20120618_202744.gpx                        NaN      NaN      NaN      NaN
# 20120622_203116.gpx                        NaN      NaN      NaN      NaN
# 20120622_205613.gpx                        NaN      NaN      NaN      NaN
# ...                                        ...      ...      ...      ...
# Running 5_27_12 7_27 pm.gpx                NaN      NaN      NaN      NaN
# Running 5_4_12 10_44 pm.gpx                NaN      NaN      NaN      NaN
# Singelloop 2016.gpx                        NaN      NaN      NaN      NaN
# Singelloop Enschede.gpx                    NaN      NaN      NaN      NaN
# Wiezoloop.gpx                              NaN      NaN      NaN      NaN
#
# [269 rows x 70 columns]

# %%
idx = pd.IndexSlice
df_final.loc[idx[:,1000],'total_distance'].sum() / 1000
# Out:
# 2437.894076948313

# %%
df_final.loc[idx[:,1000],['date','total_distance']]
# Out:
#                                                date  total_distance
# filename                section
# 20150201_105601.gpx     1000.0  2015-02-01 10:56:01     7060.048833
# 20180325_090235.gpx     1000.0  2018-03-25 09:02:35     5993.427951
# 20121127_191701.gpx     1000.0  2012-11-27 19:17:01    10137.945790
# 20160518_165805.gpx     1000.0  2016-05-18 16:58:05     7004.598062
# Nieuwe Asics GT4000.gpx 1000.0  2019-05-04 18:56:59     7973.808180
# ...                                             ...             ...
# 20190818_081719.gpx     1000.0  2019-08-18 08:17:19    16088.039483
# 20190824_080355.gpx     1000.0  2019-08-24 08:03:55    16367.937345
# 20160316_200401.gpx     1000.0  2016-03-16 20:04:01     6239.000309
# 20191211_081322.gpx     1000.0  2019-12-11 08:13:22    13303.634864
# 20170723_152756.gpx     1000.0  2017-07-23 15:27:56     5000.565117
#
# [269 rows x 2 columns]

# %%
df_total_distance = df_final.loc[idx[:,1000],['date','total_distance']]
df_total_distance
# Out:
#                                                date  total_distance
# filename                section
# 20150201_105601.gpx     1000.0  2015-02-01 10:56:01     7060.048833
# 20180325_090235.gpx     1000.0  2018-03-25 09:02:35     5993.427951
# 20121127_191701.gpx     1000.0  2012-11-27 19:17:01    10137.945790
# 20160518_165805.gpx     1000.0  2016-05-18 16:58:05     7004.598062
# Nieuwe Asics GT4000.gpx 1000.0  2019-05-04 18:56:59     7973.808180
# ...                                             ...             ...
# 20190818_081719.gpx     1000.0  2019-08-18 08:17:19    16088.039483
# 20190824_080355.gpx     1000.0  2019-08-24 08:03:55    16367.937345
# 20160316_200401.gpx     1000.0  2016-03-16 20:04:01     6239.000309
# 20191211_081322.gpx     1000.0  2019-12-11 08:13:22    13303.634864
# 20170723_152756.gpx     1000.0  2017-07-23 15:27:56     5000.565117
#
# [269 rows x 2 columns]

# %%
start_date = pd.to_datetime('2019-01-01', format='%Y-%m-%d')
end_date = pd.to_datetime('2019-12-31', format='%Y-%m-%d')
df_total_distance_2019 = df_total_distance[((df_total_distance['date'] >= start_date) & (df_total_distance['date'] <= end_date))]
df_total_distance_2019
# Out:
#                                                date  total_distance
# filename                section
# Nieuwe Asics GT4000.gpx 1000.0  2019-05-04 18:56:59     7973.808180
# 20190407_084824.gpx     1000.0  2019-04-07 08:48:24    12069.805388
# 20191012_091115.gpx     1000.0  2019-10-12 09:11:15    21138.745824
# 20190928_082644.gpx     1000.0  2019-09-28 08:26:44    17954.455656
# 20191117_101539.gpx     1000.0  2019-11-17 10:15:39     9990.222797
# ...                                             ...             ...
# 20191002_172159.gpx     1000.0  2019-10-02 17:21:59    10470.873454
# 20191208_115426.gpx     1000.0  2019-12-08 11:54:26    16081.033047
# 20190818_081719.gpx     1000.0  2019-08-18 08:17:19    16088.039483
# 20190824_080355.gpx     1000.0  2019-08-24 08:03:55    16367.937345
# 20191211_081322.gpx     1000.0  2019-12-11 08:13:22    13303.634864
#
# [76 rows x 2 columns]

# %%
print('Totale afstand 2019:')
df_total_distance_2019['total_distance'].sum() / 1000
# Out:
# Totale afstand 2019:
# 838.2463228115006

# %%
start_date = pd.to_datetime('2020-01-01', format='%Y-%m-%d')
df_total_distance_2020 = df_total_distance[(df_total_distance['date'] >= start_date)]
print('Totale afstand 2020:')
df_total_distance_2020['total_distance'].sum() / 1000
# Out:
# Totale afstand 2020:
# 111.39786003262289

# %%
start_date = pd.to_datetime('2019-02-07', format='%Y-%m-%d')
end_date = pd.to_datetime('2020-02-06', format='%Y-%m-%d')
df_total_distance_12Months = df_total_distance[((df_total_distance['date'] >= start_date) & (df_total_distance['date'] <= end_date))]
print('Totale afstand Afgelopen 12 maanden:')
df_total_distance_12Months['total_distance'].sum() / 1000
# Out:
# Totale afstand Afgelopen 12 maanden:
# 895.3811835685991

# %%
start_date = pd.to_datetime('2019-12-01', format='%Y-%m-%d')
end_date = pd.to_datetime('2020-01-01', format='%Y-%m-%d')
df_total_test = df_total_distance[((df_total_distance['date'] >= start_date) & (df_total_distance['date'] < end_date))]
print('Totale afstand test:')
df_total_test['total_distance'].sum() / 1000
# Out:
# Totale afstand test:
# 64.83358674121484

# %%
df_total_test
# Out:
#                                            date  total_distance
# filename            section
# 20191205_185918.gpx 1000.0  2019-12-05 18:59:18     8478.987585
# 20191217_185651.gpx 1000.0  2019-12-17 18:56:51     9940.295428
# 20191221_110307.gpx 1000.0  2019-12-21 11:03:07    17029.635818
# 20191208_115426.gpx 1000.0  2019-12-08 11:54:26    16081.033047
# 20191211_081322.gpx 1000.0  2019-12-11 08:13:22    13303.634864

# %% [markdown]
# 20120627_191504.gpx heeft datum 2019-08-15 gekregen.

# %%
df_final.loc[idx['20120627_191504.gpx', :], :]
# Out:
#                                time     distance  minutes_per_kilometer  \
# filename            section
# 20120627_191504.gpx 1000.00   278.0  1015.922101               4.560717
#                     1609.34   447.0  1616.484544               4.608767
#                     3000.00   840.0  3012.997734               4.646535
#                     5000.00  1415.0  5009.209722               4.707995
#                     8046.70  2292.0  8051.583228               4.744409
#
#                                            date  total_distance  total_time  \
# filename            section
# 20120627_191504.gpx 1000.00 2012-06-27 19:15:04     8595.370196      2464.0
#                     1609.34 2012-06-27 19:15:04     8595.370196      2464.0
#                     3000.00 2012-06-27 19:15:04     8595.370196      2464.0
#                     5000.00 2012-06-27 19:15:04     8595.370196      2464.0
#                     8046.70 2012-06-27 19:15:04     8595.370196      2464.0
#
#                              start_index_best_section
# filename            section
# 20120627_191504.gpx 1000.00                       327
#                     1609.34                       269
#                     3000.00                       236
#                     5000.00                       212
#                     8046.70                        17
